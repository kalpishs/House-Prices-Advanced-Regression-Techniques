# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
import warnings

import seaborn as sns
from scipy.stats import skew
from scipy.stats.stats import pearsonr
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error

# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
all_data = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'], test.loc[:,'MSSubClass':'SaleCondition']), ignore_index=True)

# %% [markdown]
# ## Imputation of missing values ##

# %%
warnings.simplefilter('ignore', np.RankWarning)
x = all_data.loc[np.logical_not(all_data["LotFrontage"].isnull()), "LotArea"]
y = all_data.loc[np.logical_not(all_data["LotFrontage"].isnull()), "LotFrontage"]

t = (x <= 25000) & (y <= 150) #Extract Values  
p = np.polyfit(x[t], y[t], 1)
all_data.loc[all_data['LotFrontage'].isnull(), 'LotFrontage'] = np.polyval(p, all_data.loc[all_data['LotFrontage'].isnull(), 'LotArea'])

# %% [markdown]
# There are many features were NaN should be considered as absence of such property. In other cases I replace NaN with most common value

# %%
all_data = all_data.fillna({
    'Alley' : 'NoAlley',
    'MasVnrType': 'None',
    'FireplaceQu': 'NoFireplace',
    'GarageType': 'NoGarage',
    'GarageFinish': 'NoGarage',
    'GarageQual': 'NoGarage',
    'GarageCond': 'NoGarage',
    'BsmtFullBath': 0,
    'BsmtHalfBath': 0,
    'BsmtQual' : 'NoBsmt',
    'BsmtCond' : 'NoBsmt',
    'BsmtExposure' : 'NoBsmt',
    'BsmtFinType1' : 'NoBsmt',
    'BsmtFinType2' : 'NoBsmt',
    'KitchenQual' : 'TA',
    'MSZoning' : 'RL',
    'Utilities' : 'AllPub',
    'Exterior1st' : 'VinylSd',
    'Exterior2nd'   : 'VinylSd',
    'Functional' : 'Typ',
    'PoolQC' : 'NoPool',
    'Fence' : 'NoFence',
    'MiscFeature' : 'None',
    'Electrical' : 'SBrkr'
     
})


all_data.loc[all_data.SaleCondition.isnull(), 'SaleCondition'] = 'Normal'
all_data.loc[all_data.SaleCondition.isnull(), 'SaleType'] = 'WD'
all_data.loc[all_data.MasVnrType == 'None', 'MasVnrArea'] = 0
all_data.loc[all_data.BsmtFinType1=='NoBsmt', 'BsmtFinSF1'] = 0
all_data.loc[all_data.BsmtFinType2=='NoBsmt', 'BsmtFinSF2'] = 0
all_data.loc[all_data.BsmtFinSF1.isnull(), 'BsmtFinSF1'] = all_data.BsmtFinSF1.median()
all_data.loc[all_data.BsmtQual=='NoBsmt', 'BsmtUnfSF'] = 0
all_data.loc[all_data.BsmtUnfSF.isnull(), 'BsmtUnfSF'] = all_data.BsmtUnfSF.median()
all_data.loc[all_data.BsmtQual=='NoBsmt', 'TotalBsmtSF'] = 0

# only one is null and it has type Detchd
all_data.loc[all_data['GarageArea'].isnull(), 'GarageArea'] = all_data.loc[all_data['GarageType']=='Detchd', 'GarageArea'].mean()
all_data.loc[all_data['GarageCars'].isnull(), 'GarageCars'] = all_data.loc[all_data['GarageType']=='Detchd', 'GarageCars'].median()

# %% [markdown]
# ## Normalization ##

# %%
# where we have order we will use numeric
all_data = all_data.replace({'Utilities': {'AllPub': 1, 'NoSeWa': 0, 'NoSewr': 0, 'ELO': 0},
                             'Street': {'Pave': 1, 'Grvl': 0 },
                             'FireplaceQu': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1,
                                            'NoFireplace': 0 
                                            },
                             'Fence': {'GdPrv': 2, 
                                       'GdWo': 2, 
                                       'MnPrv': 1, 
                                       'MnWw': 1,
                                       'NoFence': 0},
                             'ExterQual': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1
                                            },
                             'ExterCond': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1
                                            },
                             'BsmtQual': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1,
                                            'NoBsmt': 0},
                             'BsmtExposure': {'Gd': 3, 
                                            'Av': 2, 
                                            'Mn': 1,
                                            'No': 0,
                                            'NoBsmt': 0},
                             'BsmtCond': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1,
                                            'NoBsmt': 0},
                             'GarageQual': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1,
                                            'NoGarage': 0},
                             'GarageCond': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1,
                                            'NoGarage': 0},
                             'KitchenQual': {'Ex': 5, 
                                            'Gd': 4, 
                                            'TA': 3, 
                                            'Fa': 2,
                                            'Po': 1},
                             'Functional': {'Typ': 0,
                                            'Min1': 1,
                                            'Min2': 1,
                                            'Mod': 2,
                                            'Maj1': 3,
                                            'Maj2': 4,
                                            'Sev': 5,
                                            'Sal': 6}                             
                            })


all_data = all_data.replace({'CentralAir': {'Y': 1, 
                                            'N': 0}})
all_data = all_data.replace({'PavedDrive': {'Y': 1, 
                                            'P': 0,
                                            'N': 0}})

# %%
newer_dwelling = all_data.MSSubClass.replace({20: 1, 
                                            30: 0, 
                                            40: 0, 
                                            45: 0,
                                            50: 0, 
                                            60: 1,
                                            70: 0,
                                            75: 0,
                                            80: 0,
                                            85: 0,
                                            90: 0,
                                           120: 1,
                                           150: 0,
                                           160: 0,
                                           180: 0,
                                           190: 0})
newer_dwelling.name = 'newer_dwelling'

# %%
all_data = all_data.replace({'MSSubClass': {20: 'SubClass_20', 
                                            30: 'SubClass_30', 
                                            40: 'SubClass_40', 
                                            45: 'SubClass_45',
                                            50: 'SubClass_50', 
                                            60: 'SubClass_60',
                                            70: 'SubClass_70',
                                            75: 'SubClass_75',
                                            80: 'SubClass_80',
                                            85: 'SubClass_85',
                                            90: 'SubClass_90',
                                           120: 'SubClass_120',
                                           150: 'SubClass_150',
                                           160: 'SubClass_160',
                                           180: 'SubClass_180',
                                           190: 'SubClass_190'}})

# %%
# The idea is good quality should rise price, poor quality - reduce price
overall_poor_qu = all_data.OverallQual.copy()
overall_poor_qu = 5 - overall_poor_qu
overall_poor_qu[overall_poor_qu<0] = 0
overall_poor_qu.name = 'overall_poor_qu'

overall_good_qu = all_data.OverallQual.copy()
overall_good_qu = overall_good_qu - 5
overall_good_qu[overall_good_qu<0] = 0
overall_good_qu.name = 'overall_good_qu'

overall_poor_cond = all_data.OverallCond.copy()
overall_poor_cond = 5 - overall_poor_cond
overall_poor_cond[overall_poor_cond<0] = 0
overall_poor_cond.name = 'overall_poor_cond'

overall_good_cond = all_data.OverallCond.copy()
overall_good_cond = overall_good_cond - 5
overall_good_cond[overall_good_cond<0] = 0
overall_good_cond.name = 'overall_good_cond'

exter_poor_qu = all_data.ExterQual.copy()
exter_poor_qu[exter_poor_qu<3] = 1
exter_poor_qu[exter_poor_qu>=3] = 0
exter_poor_qu.name = 'exter_poor_qu'

exter_good_qu = all_data.ExterQual.copy()
exter_good_qu[exter_good_qu<=3] = 0
exter_good_qu[exter_good_qu>3] = 1
exter_good_qu.name = 'exter_good_qu'

exter_poor_cond = all_data.ExterCond.copy()
exter_poor_cond[exter_poor_cond<3] = 1
exter_poor_cond[exter_poor_cond>=3] = 0
exter_poor_cond.name = 'exter_poor_cond'

exter_good_cond = all_data.ExterCond.copy()
exter_good_cond[exter_good_cond<=3] = 0
exter_good_cond[exter_good_cond>3] = 1
exter_good_cond.name = 'exter_good_cond'

bsmt_poor_cond = all_data.BsmtCond.copy()
bsmt_poor_cond[bsmt_poor_cond<3] = 1
bsmt_poor_cond[bsmt_poor_cond>=3] = 0
bsmt_poor_cond.name = 'bsmt_poor_cond'

bsmt_good_cond = all_data.BsmtCond.copy()
bsmt_good_cond[bsmt_good_cond<=3] = 0
bsmt_good_cond[bsmt_good_cond>3] = 1
bsmt_good_cond.name = 'bsmt_good_cond'

garage_poor_qu = all_data.GarageQual.copy()
garage_poor_qu[garage_poor_qu<3] = 1
garage_poor_qu[garage_poor_qu>=3] = 0
garage_poor_qu.name = 'garage_poor_qu'

garage_good_qu = all_data.GarageQual.copy()
garage_good_qu[garage_good_qu<=3] = 0
garage_good_qu[garage_good_qu>3] = 1
garage_good_qu.name = 'garage_good_qu'

garage_poor_cond = all_data.GarageCond.copy()
garage_poor_cond[garage_poor_cond<3] = 1
garage_poor_cond[garage_poor_cond>=3] = 0
garage_poor_cond.name = 'garage_poor_cond'

garage_good_cond = all_data.GarageCond.copy()
garage_good_cond[garage_good_cond<=3] = 0
garage_good_cond[garage_good_cond>3] = 1
garage_good_cond.name = 'garage_good_cond'

kitchen_poor_qu = all_data.KitchenQual.copy()
kitchen_poor_qu[kitchen_poor_qu<3] = 1
kitchen_poor_qu[kitchen_poor_qu>=3] = 0
kitchen_poor_qu.name = 'kitchen_poor_qu'

kitchen_good_qu = all_data.KitchenQual.copy()
kitchen_good_qu[kitchen_good_qu<=3] = 0
kitchen_good_qu[kitchen_good_qu>3] = 1
kitchen_good_qu.name = 'kitchen_good_qu'

qu_list = pd.concat((overall_poor_qu, overall_good_qu, overall_poor_cond, overall_good_cond, exter_poor_qu,
                     exter_good_qu, exter_poor_cond, exter_good_cond, bsmt_poor_cond, bsmt_good_cond, garage_poor_qu,
                     garage_good_qu, garage_poor_cond, garage_good_cond, kitchen_poor_qu, kitchen_good_qu), axis=1)



bad_heating = all_data.HeatingQC.replace({'Ex': 0, 
                                          'Gd': 0, 
                                          'TA': 0, 
                                          'Fa': 1,
                                          'Po': 1})
bad_heating.name = 'bad_heating'
                                          
MasVnrType_Any = all_data.MasVnrType.replace({'BrkCmn': 1,
                                              'BrkFace': 1,
                                              'CBlock': 1,
                                              'Stone': 1,
                                              'None': 0})
MasVnrType_Any.name = 'MasVnrType_Any'

SaleCondition_PriceDown = all_data.SaleCondition.replace({'Abnorml': 1,
                                                          'Alloca': 1,
                                                          'AdjLand': 1,
                                                          'Family': 1,
                                                          'Normal': 0,
                                                          'Partial': 0})
SaleCondition_PriceDown.name = 'SaleCondition_PriceDown'

Neighborhood_Good = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['Neighborhood_Good'])
Neighborhood_Good[all_data.Neighborhood=='NridgHt'] = 1
Neighborhood_Good[all_data.Neighborhood=='Crawfor'] = 1
Neighborhood_Good[all_data.Neighborhood=='StoneBr'] = 1
Neighborhood_Good[all_data.Neighborhood=='Somerst'] = 1
Neighborhood_Good[all_data.Neighborhood=='NoRidge'] = 1

# %%
from sklearn.svm import SVC
svm = SVC(C=100, gamma=0.0001, kernel='rbf')
pc = pd.Series(np.zeros(train.shape[0]))

pc[:] = 'pc1'
pc[train.SalePrice >= 150000] = 'pc2'
pc[train.SalePrice >= 220000] = 'pc3'
columns_for_pc = ['Exterior1st', 'Exterior2nd', 'RoofMatl', 'Condition1', 'Condition2', 'BldgType']
X_t = pd.get_dummies(train.loc[:, columns_for_pc], sparse=True)
svm.fit(X_t, pc) #Training
pc_pred = svm.predict(X_t)

p = train.SalePrice/100000

price_category = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['pc'])
X_t = pd.get_dummies(all_data.loc[:, columns_for_pc], sparse=True)
pc_pred = svm.predict(X_t)
price_category[pc_pred=='pc2'] = 1
price_category[pc_pred=='pc3'] = 2

price_category = price_category.to_sparse()

# %%
# Monthes with the lagest number of deals may be significant
season = all_data.MoSold.replace( {1: 0, 
                                   2: 0, 
                                   3: 0, 
                                   4: 1,
                                   5: 1, 
                                   6: 1,
                                   7: 1,
                                   8: 0,
                                   9: 0,
                                  10: 0,
                                  11: 0,
                                  12: 0})
season.name = 'season'

# Numer month is not significant
all_data = all_data.replace({'MoSold': {1: 'Yan', 
                                        2: 'Feb', 
                                        3: 'Mar', 
                                        4: 'Apr',
                                        5: 'May', 
                                        6: 'Jun',
                                        7: 'Jul',
                                        8: 'Avg',
                                        9: 'Sep',
                                        10: 'Oct',
                                        11: 'Nov',
                                        12: 'Dec'}})

# %%
reconstruct = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['Reconstruct'])
reconstruct[all_data.YrSold < all_data.YearRemodAdd] = 1
reconstruct = reconstruct.to_sparse()

recon_after_buy = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['ReconstructAfterBuy'])
recon_after_buy[all_data.YearRemodAdd >= all_data.YrSold] = 1
recon_after_buy = recon_after_buy.to_sparse()

build_eq_buy = pd.DataFrame(np.zeros((all_data.shape[0],1)), columns=['Build.eq.Buy'])
build_eq_buy[all_data.YearBuilt >= all_data.YrSold] = 1
build_eq_buy = build_eq_buy.to_sparse()

# %%
# I hope this will help
all_data.YrSold = 2010 - all_data.YrSold

# %%
year_map = pd.concat(pd.Series('YearGroup' + str(i+1), index=range(1871+i*20,1891+i*20)) for i in range(0, 7))
all_data.GarageYrBlt = all_data.GarageYrBlt.map(year_map)
all_data.loc[all_data['GarageYrBlt'].isnull(), 'GarageYrBlt'] = 'NoGarage'

# %%
all_data.YearBuilt = all_data.YearBuilt.map(year_map)
all_data.YearRemodAdd = all_data.YearRemodAdd.map(year_map)

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index
t = all_data[numeric_feats].quantile(.75)
use_75_scater = t[t != 0].index
all_data[use_75_scater] = all_data[use_75_scater]/all_data[use_75_scater].quantile(.75)

# %%
t = ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 
     '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 
     'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']

all_data.loc[:, t] = np.log1p(all_data.loc[:, t])
train["SalePrice"] = np.log1p(train["SalePrice"])

# %%
# all classes in sklearn requires numeric data only
# transform categorical variable into binary
X = pd.get_dummies(all_data)
X = X.fillna(X.mean())

# %%
X = X.drop('RoofMatl_ClyTile', axis=1) # only one is not zero
X = X.drop('Condition2_PosN', axis=1) # only two is not zero
X = X.drop('MSZoning_C (all)', axis=1)
X = X.drop('MSSubClass_SubClass_160', axis=1)
# this features definitely cause overfitting

# %%
# add new features
X = pd.concat((X, newer_dwelling, season, reconstruct, recon_after_buy,
               qu_list, bad_heating, MasVnrType_Any, price_category, build_eq_buy), axis=1)

# %%
from itertools import product, chain

def poly(X):
    areas = ['LotArea', 'TotalBsmtSF', 'GrLivArea', 'GarageArea', 'BsmtUnfSF']
    t = chain(qu_list.axes[1].get_values(), 
              ['OverallQual', 'OverallCond', 'ExterQual', 'ExterCond', 'BsmtCond', 'GarageQual', 'GarageCond',
               'KitchenQual', 'HeatingQC', 'bad_heating', 'MasVnrType_Any', 'SaleCondition_PriceDown', 'Reconstruct',
               'ReconstructAfterBuy', 'Build.eq.Buy'])
    for a, t in product(areas, t):
        x = X.loc[:, [a, t]].prod(1)
        x.name = a + '_' + t
        yield x

XP = pd.concat(poly(X), axis=1)
X = pd.concat((X, XP), axis=1)

# %%
X_train = X[:train.shape[0]]
X_test = X[train.shape[0]:]
y = train.SalePrice

# %%
#outliers_id = np.array([31, 463, 524, 633, 969, 971, 1299, 1325])
outliers_id = np.array([523,1298])


X_train = X_train.drop(outliers_id)
y = y.drop(outliers_id)

# %%
from sklearn.linear_model import Ridge, RidgeCV, ElasticNet, LassoCV, LassoLarsCV
from sklearn.model_selection import cross_val_score

def rmse_cv(model):
    rmse= np.sqrt(-cross_val_score(model, X_train, y, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

lasso_model = LassoCV(alphas = [1, 0.1, 0.001, 0.0005, 5e-4]).fit(X_train, y)
from operator import itemgetter

# %%
import itertools
import xgboost as xgb
from sklearn.cross_validation import KFold
dtrain = xgb.DMatrix(X_train, label = y)
dtest = xgb.DMatrix(X_test)  

eta = 0.01
max_depth = 6
subsample = 1 # No subsampling, as we already use Kfold latter and we don't have that much data
colsample_bytree = 1

num_boost_round = 5500 # for small eta, increase this one
early_stopping_rounds = 500
n_folds=5


# start the training
array_score=np.ndarray((len(eta_list)*len(max_depth_list),4)) # store score values
print('XGBoost params. ETA: {}, MAX_DEPTH: {}'.format(eta, max_depth))
params = {
    "objective": "reg:linear",
    "booster" : "gbtree",
    "eval_metric": "rmse",
    "eta": eta, # shrinking parameters to prevent overfitting
    "tree_method": 'exact',
    "max_depth": max_depth,
    "subsample": subsample, # collect 80% of the data only to prevent overfitting
    "colsample_bytree": colsample_bytree,
    "silent": 1,
    "seed": 0,
}
kf = KFold(len(train), n_folds=n_folds)
test_prediction=np.ndarray((n_folds,len(X_test)))
fold=0
fold_score=[]
for train_index, cv_index in kf:
    dtrain = xgb.DMatrix(X_train, label = y)

    watchlist = [(dtrain, 'train')] # list of things to evaluate and print
    gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=early_stopping_rounds, verbose_eval=True) # find the best score

    print("Validating...")
    score = gbm.best_score
    print('Check last score value: {:.6f}'.format(score))
    fold_score.append(score)
    importance = gbm.get_fscore()
    importance = sorted(importance.items(), key=itemgetter(1), reverse=True)
    print('Importance array for fold {} :\n {}'.format(fold, importance))
    #np.save("features_importance",importance)
    print("Predict test set...")
    prediction=np.expm1(gbm.predict(dtest))
    #np.save("prediction_eta%s_depth%s_fold%s" %(eta,max_depth,fold),prediction) # You can save all the folds prediction to check for errors in code
    test_prediction[fold]=prediction
    fold = fold + 1
    
mean_score=np.mean(fold_score)
print("Mean Score : {}, eta : {}, depth : {}\n".format(mean_score,eta,max_depth))
array_score[i][0]=eta
array_score[i][1]=max_depth
array_score[i][2]=mean_score
array_score[i][3]=np.std(fold_score)
    
x_pred=test_prediction.mean(axis=0)
df_score=pd.DataFrame(array_score,columns=['eta','max_depth','mean_score','std_score'])
print ("df_score : \n", df_score)# get the complete array of scores to choose the right parameters
# Out:
# XGBoost params. ETA: 0.01, MAX_DEPTH: 6
# [0]	train-rmse:11.4159
# Will train until train-rmse hasn't improved in 500 rounds.
# [1]	train-rmse:11.3019
# [2]	train-rmse:11.1891
# [3]	train-rmse:11.0774
# [4]	train-rmse:10.9669
# [5]	train-rmse:10.8574
# [6]	train-rmse:10.7491
# [7]	train-rmse:10.6418
# [8]	train-rmse:10.5356
# [9]	train-rmse:10.4305
# [10]	train-rmse:10.3264
# [11]	train-rmse:10.2234
# [12]	train-rmse:10.1213
# [13]	train-rmse:10.0204
# [14]	train-rmse:9.92037
# [15]	train-rmse:9.82138
# [16]	train-rmse:9.72338
# [17]	train-rmse:9.62637
# [18]	train-rmse:9.53032
# [19]	train-rmse:9.43523
# [20]	train-rmse:9.34109
# [21]	train-rmse:9.24789
# [22]	train-rmse:9.15563
# [23]	train-rmse:9.06428
# [24]	train-rmse:8.97385
# [25]	train-rmse:8.88432
# [26]	train-rmse:8.79569
# [27]	train-rmse:8.70794
# [28]	train-rmse:8.62106
# [29]	train-rmse:8.53506
# [30]	train-rmse:8.44992
# [31]	train-rmse:8.36562
# [32]	train-rmse:8.28217
# [33]	train-rmse:8.19956
# [34]	train-rmse:8.11777
# [35]	train-rmse:8.03679
# [36]	train-rmse:7.95663
# [37]	train-rmse:7.87726
# [38]	train-rmse:7.79869
# [39]	train-rmse:7.72091
# [40]	train-rmse:7.6439
# [41]	train-rmse:7.56766
# [42]	train-rmse:7.49219
# [43]	train-rmse:7.41746
# [44]	train-rmse:7.34349
# [45]	train-rmse:7.27025
# [46]	train-rmse:7.19775
# [47]	train-rmse:7.12597
# [48]	train-rmse:7.05491
# [49]	train-rmse:6.98456
# [50]	train-rmse:6.91491
# [51]	train-rmse:6.84595
# [52]	train-rmse:6.77769
# [53]	train-rmse:6.71011
# [54]	train-rmse:6.6432
# [55]	train-rmse:6.57697
# [56]	train-rmse:6.51139
# [57]	train-rmse:6.44647
# [58]	train-rmse:6.3822
# [59]	train-rmse:6.31857
# [60]	train-rmse:6.25558
# [61]	train-rmse:6.19322
# [62]	train-rmse:6.13148
# [63]	train-rmse:6.07036
# [64]	train-rmse:6.00985
# [65]	train-rmse:5.94994
# [66]	train-rmse:5.89063
# [67]	train-rmse:5.83192
# [68]	train-rmse:5.77379
# [69]	train-rmse:5.71625
# [70]	train-rmse:5.65928
# [71]	train-rmse:5.60288
# [72]	train-rmse:5.54704
# [73]	train-rmse:5.49176
# [74]	train-rmse:5.43703
# [75]	train-rmse:5.38286
# [76]	train-rmse:5.32922
# [77]	train-rmse:5.27612
# [78]	train-rmse:5.22355
# [79]	train-rmse:5.1715
# [80]	train-rmse:5.11998
# [81]	train-rmse:5.06897
# [82]	train-rmse:5.01847
# [83]	train-rmse:4.96848
# [84]	train-rmse:4.91899
# [85]	train-rmse:4.86999
# [86]	train-rmse:4.82148
# [87]	train-rmse:4.77346
# [88]	train-rmse:4.72592
# [89]	train-rmse:4.67885
# [90]	train-rmse:4.63225
# [91]	train-rmse:4.58612
# [92]	train-rmse:4.54045
# [93]	train-rmse:4.49524
# [94]	train-rmse:4.45048
# [95]	train-rmse:4.40616
# [96]	train-rmse:4.36229
# [97]	train-rmse:4.31886
# [98]	train-rmse:4.27586
# [99]	train-rmse:4.2333
# [100]	train-rmse:4.19115
# [101]	train-rmse:4.14943
# [102]	train-rmse:4.10813
# [103]	train-rmse:4.06724
# [104]	train-rmse:4.02675
# [105]	train-rmse:3.98668
# [106]	train-rmse:3.947
# [107]	train-rmse:3.90772
# [108]	train-rmse:3.86883
# [109]	train-rmse:3.83033
# [110]	train-rmse:3.79222
# [111]	train-rmse:3.75449
# [112]	train-rmse:3.71713
# [113]	train-rmse:3.68015
# [114]	train-rmse:3.64353
# [115]	train-rmse:3.60729
# [116]	train-rmse:3.5714
# [117]	train-rmse:3.53588
# [118]	train-rmse:3.50071
# [119]	train-rmse:3.46589
# [120]	train-rmse:3.43142
# [121]	train-rmse:3.3973
# [122]	train-rmse:3.36351
# [123]	train-rmse:3.33006
# [124]	train-rmse:3.29695
# [125]	train-rmse:3.26417
# [126]	train-rmse:3.23172
# [127]	train-rmse:3.19959
# [128]	train-rmse:3.16778
# [129]	train-rmse:3.13629
# [130]	train-rmse:3.10511
# [131]	train-rmse:3.07425
# [132]	train-rmse:3.04369
# [133]	train-rmse:3.01344
# [134]	train-rmse:2.9835
# [135]	train-rmse:2.95385
# [136]	train-rmse:2.9245
# [137]	train-rmse:2.89544
# [138]	train-rmse:2.86667
# [139]	train-rmse:2.83819
# [140]	train-rmse:2.80999
# [141]	train-rmse:2.78208
# [142]	train-rmse:2.75445
# [143]	train-rmse:2.72709
# [144]	train-rmse:2.7
# [145]	train-rmse:2.67319
# [146]	train-rmse:2.64665
# [147]	train-rmse:2.62037
# [148]	train-rmse:2.59435
# [149]	train-rmse:2.5686
# [150]	train-rmse:2.5431
# [151]	train-rmse:2.51785
# [152]	train-rmse:2.49286
# [153]	train-rmse:2.46812
# [154]	train-rmse:2.44362
# [155]	train-rmse:2.41937
# [156]	train-rmse:2.39537
# [157]	train-rmse:2.3716
# [158]	train-rmse:2.34807
# [159]	train-rmse:2.32478
# [160]	train-rmse:2.30172
# [161]	train-rmse:2.27889
# [162]	train-rmse:2.25629
# [163]	train-rmse:2.23391
# [164]	train-rmse:2.21176
# [165]	train-rmse:2.18982
# [166]	train-rmse:2.16812
# [167]	train-rmse:2.14662
# [168]	train-rmse:2.12535
# [169]	train-rmse:2.10428
# [170]	train-rmse:2.08343
# [171]	train-rmse:2.06278
# [172]	train-rmse:2.04234
# [173]	train-rmse:2.02211
# [174]	train-rmse:2.00208
# [175]	train-rmse:1.98224
# [176]	train-rmse:1.96261
# [177]	train-rmse:1.94318
# [178]	train-rmse:1.92394
# [179]	train-rmse:1.90489
# [180]	train-rmse:1.88603
# [181]	train-rmse:1.86736
# [182]	train-rmse:1.84888
# [183]	train-rmse:1.83058
# [184]	train-rmse:1.81247
# [185]	train-rmse:1.79454
# [186]	train-rmse:1.77679
# [187]	train-rmse:1.75921
# [188]	train-rmse:1.74181
# [189]	train-rmse:1.72459
# [190]	train-rmse:1.70754
# [191]	train-rmse:1.69066
# [192]	train-rmse:1.67394
# [193]	train-rmse:1.6574
# [194]	train-rmse:1.64101
# [195]	train-rmse:1.6248
# [196]	train-rmse:1.60875
# [197]	train-rmse:1.59286
# [198]	train-rmse:1.57713
# [199]	train-rmse:1.56156
# [200]	train-rmse:1.54614
# [201]	train-rmse:1.53087
# [202]	train-rmse:1.51575
# [203]	train-rmse:1.50079
# [204]	train-rmse:1.48598
# [205]	train-rmse:1.47131
# [206]	train-rmse:1.45679
# [207]	train-rmse:1.44242
# [208]	train-rmse:1.42819
# [209]	train-rmse:1.41411
# [210]	train-rmse:1.40017
# [211]	train-rmse:1.38636
# [212]	train-rmse:1.3727
# [213]	train-rmse:1.35917
# [214]	train-rmse:1.34578
# [215]	train-rmse:1.33252
# [216]	train-rmse:1.31939
# [217]	train-rmse:1.3064
# [218]	train-rmse:1.29353
# [219]	train-rmse:1.2808
# [220]	train-rmse:1.26819
# [221]	train-rmse:1.25571
# [222]	train-rmse:1.24336
# [223]	train-rmse:1.23113
# [224]	train-rmse:1.21902
# [225]	train-rmse:1.20703
# [226]	train-rmse:1.19516
# [227]	train-rmse:1.18341
# [228]	train-rmse:1.17178
# [229]	train-rmse:1.16027
# [230]	train-rmse:1.14886
# [231]	train-rmse:1.13758
# [232]	train-rmse:1.12641
# [233]	train-rmse:1.11535
# [234]	train-rmse:1.1044
# [235]	train-rmse:1.09356
# [236]	train-rmse:1.08283
# [237]	train-rmse:1.07221
# [238]	train-rmse:1.0617
# [239]	train-rmse:1.05129
# [240]	train-rmse:1.04098
# [241]	train-rmse:1.03078
# [242]	train-rmse:1.02068
# [243]	train-rmse:1.01069
# [244]	train-rmse:1.00079
# [245]	train-rmse:0.990989
# [246]	train-rmse:0.981288
# [247]	train-rmse:0.971689
# [248]	train-rmse:0.962182
# [249]	train-rmse:0.952775
# [250]	train-rmse:0.943458
# [251]	train-rmse:0.934231
# [252]	train-rmse:0.925101
# [253]	train-rmse:0.916066
# [254]	train-rmse:0.907118
# [255]	train-rmse:0.898262
# [256]	train-rmse:0.889495
# [257]	train-rmse:0.880816
# [258]	train-rmse:0.872225
# [259]	train-rmse:0.863719
# [260]	train-rmse:0.8553
# [261]	train-rmse:0.846959
# [262]	train-rmse:0.838708
# [263]	train-rmse:0.830541
# [264]	train-rmse:0.822455
# [265]	train-rmse:0.814444
# [266]	train-rmse:0.80652
# [267]	train-rmse:0.798676
# [268]	train-rmse:0.790912
# [269]	train-rmse:0.783227
# [270]	train-rmse:0.77562
# [271]	train-rmse:0.768088
# [272]	train-rmse:0.760623
# [273]	train-rmse:0.753244
# [274]	train-rmse:0.745938
# [275]	train-rmse:0.738696
# [276]	train-rmse:0.731531
# [277]	train-rmse:0.724443
# [278]	train-rmse:0.717426
# [279]	train-rmse:0.710483
# [280]	train-rmse:0.703606
# [281]	train-rmse:0.696792
# [282]	train-rmse:0.690053
# [283]	train-rmse:0.683382
# [284]	train-rmse:0.67678
# [285]	train-rmse:0.670243
# [286]	train-rmse:0.663766
# [287]	train-rmse:0.657355
# [288]	train-rmse:0.651016
# [289]	train-rmse:0.644734
# [290]	train-rmse:0.63852
# [291]	train-rmse:0.63237
# [292]	train-rmse:0.626275
# [293]	train-rmse:0.620246
# [294]	train-rmse:0.614275
# [295]	train-rmse:0.608363
# [296]	train-rmse:0.602517
# [297]	train-rmse:0.596731
# [298]	train-rmse:0.590999
# [299]	train-rmse:0.58532
# [300]	train-rmse:0.579707
# [301]	train-rmse:0.574142
# [302]	train-rmse:0.568644
# [303]	train-rmse:0.563192
# [304]	train-rmse:0.557796
# [305]	train-rmse:0.552454
# [306]	train-rmse:0.547169
# [307]	train-rmse:0.541934
# [308]	train-rmse:0.536755
# [309]	train-rmse:0.531626
# [310]	train-rmse:0.526553
# [311]	train-rmse:0.521528
# [312]	train-rmse:0.516559
# [313]	train-rmse:0.511642
# [314]	train-rmse:0.506768
# [315]	train-rmse:0.501944
# [316]	train-rmse:0.49717
# [317]	train-rmse:0.492446
# [318]	train-rmse:0.487774
# [319]	train-rmse:0.483145
# [320]	train-rmse:0.478561
# [321]	train-rmse:0.474023
# [322]	train-rmse:0.469534
# [323]	train-rmse:0.465087
# [324]	train-rmse:0.46069
# [325]	train-rmse:0.456337
# [326]	train-rmse:0.452027
# [327]	train-rmse:0.447763
# [328]	train-rmse:0.443538
# [329]	train-rmse:0.439356
# [330]	train-rmse:0.435214
# [331]	train-rmse:0.431112
# [332]	train-rmse:0.427056
# [333]	train-rmse:0.423038
# [334]	train-rmse:0.419064
# [335]	train-rmse:0.415133
# [336]	train-rmse:0.41124
# [337]	train-rmse:0.407386
# [338]	train-rmse:0.403567
# [339]	train-rmse:0.39979
# [340]	train-rmse:0.39605
# [341]	train-rmse:0.392354
# [342]	train-rmse:0.388688
# [343]	train-rmse:0.385065
# [344]	train-rmse:0.381476
# [345]	train-rmse:0.37793
# [346]	train-rmse:0.374417
# [347]	train-rmse:0.370938
# [348]	train-rmse:0.367497
# [349]	train-rmse:0.36409
# [350]	train-rmse:0.360721
# [351]	train-rmse:0.357381
# [352]	train-rmse:0.354076
# [353]	train-rmse:0.350802
# [354]	train-rmse:0.347567
# [355]	train-rmse:0.344363
# [356]	train-rmse:0.341195
# [357]	train-rmse:0.338058
# [358]	train-rmse:0.334952
# [359]	train-rmse:0.33188
# [360]	train-rmse:0.328838
# [361]	train-rmse:0.325827
# [362]	train-rmse:0.322852
# [363]	train-rmse:0.319902
# [364]	train-rmse:0.316981
# [365]	train-rmse:0.314085
# [366]	train-rmse:0.311224
# [367]	train-rmse:0.308386
# [368]	train-rmse:0.305588
# [369]	train-rmse:0.302822
# [370]	train-rmse:0.300085
# [371]	train-rmse:0.297375
# [372]	train-rmse:0.294693
# [373]	train-rmse:0.29204
# [374]	train-rmse:0.289411
# [375]	train-rmse:0.286809
# [376]	train-rmse:0.284233
# [377]	train-rmse:0.281683
# [378]	train-rmse:0.279164
# [379]	train-rmse:0.276664
# [380]	train-rmse:0.274192
# [381]	train-rmse:0.271748
# [382]	train-rmse:0.269324
# [383]	train-rmse:0.266937
# [384]	train-rmse:0.264564
# [385]	train-rmse:0.262215
# [386]	train-rmse:0.259892
# [387]	train-rmse:0.257599
# [388]	train-rmse:0.255327
# [389]	train-rmse:0.253075
# [390]	train-rmse:0.250851
# [391]	train-rmse:0.248644
# [392]	train-rmse:0.246464
# [393]	train-rmse:0.244314
# [394]	train-rmse:0.242169
# [395]	train-rmse:0.240061
# [396]	train-rmse:0.237972
# [397]	train-rmse:0.235909
# [398]	train-rmse:0.233865
# [399]	train-rmse:0.23183
# [400]	train-rmse:0.229829
# [401]	train-rmse:0.227841
# [402]	train-rmse:0.225887
# [403]	train-rmse:0.223953
# [404]	train-rmse:0.222039
# [405]	train-rmse:0.220147
# [406]	train-rmse:0.218271
# [407]	train-rmse:0.216413
# [408]	train-rmse:0.214565
# [409]	train-rmse:0.212754
# [410]	train-rmse:0.210946
# [411]	train-rmse:0.209161
# [412]	train-rmse:0.207404
# [413]	train-rmse:0.205652
# [414]	train-rmse:0.203937
# [415]	train-rmse:0.202221
# [416]	train-rmse:0.200535
# [417]	train-rmse:0.198872
# [418]	train-rmse:0.197215
# [419]	train-rmse:0.195591
# [420]	train-rmse:0.193982
# [421]	train-rmse:0.192386
# [422]	train-rmse:0.190811
# [423]	train-rmse:0.189241
# [424]	train-rmse:0.187694
# [425]	train-rmse:0.186165
# [426]	train-rmse:0.184647
# [427]	train-rmse:0.18316
# [428]	train-rmse:0.181687
# [429]	train-rmse:0.180224
# [430]	train-rmse:0.178766
# [431]	train-rmse:0.177329
# [432]	train-rmse:0.175923
# [433]	train-rmse:0.174525
# [434]	train-rmse:0.173143
# [435]	train-rmse:0.171776
# [436]	train-rmse:0.17043
# [437]	train-rmse:0.169084
# [438]	train-rmse:0.167769
# [439]	train-rmse:0.16646
# [440]	train-rmse:0.165173
# [441]	train-rmse:0.163884
# [442]	train-rmse:0.162622
# [443]	train-rmse:0.16137
# [444]	train-rmse:0.160125
# [445]	train-rmse:0.158903
# [446]	train-rmse:0.157696
# [447]	train-rmse:0.156509
# [448]	train-rmse:0.155326
# [449]	train-rmse:0.15415
# [450]	train-rmse:0.153005
# [451]	train-rmse:0.151856
# [452]	train-rmse:0.150725
# [453]	train-rmse:0.1496
# [454]	train-rmse:0.148508
# [455]	train-rmse:0.147411
# [456]	train-rmse:0.14631
# [457]	train-rmse:0.145255
# [458]	train-rmse:0.144196
# [459]	train-rmse:0.143166
# [460]	train-rmse:0.142111
# [461]	train-rmse:0.141092
# [462]	train-rmse:0.140061
# [463]	train-rmse:0.139052
# [464]	train-rmse:0.138066
# [465]	train-rmse:0.137073
# [466]	train-rmse:0.136106
# [467]	train-rmse:0.135164
# [468]	train-rmse:0.13421
# [469]	train-rmse:0.133292
# [470]	train-rmse:0.13236
# [471]	train-rmse:0.131449
# [472]	train-rmse:0.130535
# [473]	train-rmse:0.129622
# [474]	train-rmse:0.128739
# [475]	train-rmse:0.127885
# [476]	train-rmse:0.127004
# [477]	train-rmse:0.126161
# [478]	train-rmse:0.12531
# [479]	train-rmse:0.124492
# [480]	train-rmse:0.123663
# [481]	train-rmse:0.122868
# [482]	train-rmse:0.122052
# [483]	train-rmse:0.121258
# [484]	train-rmse:0.120466
# [485]	train-rmse:0.119683
# [486]	train-rmse:0.118933
# [487]	train-rmse:0.118198
# [488]	train-rmse:0.117446
# [489]	train-rmse:0.116726
# [490]	train-rmse:0.116
# [491]	train-rmse:0.115267
# [492]	train-rmse:0.114547
# [493]	train-rmse:0.11386
# [494]	train-rmse:0.113147
# [495]	train-rmse:0.112477
# [496]	train-rmse:0.111793
# [497]	train-rmse:0.111129
# [498]	train-rmse:0.110461
# [499]	train-rmse:0.109813
# [500]	train-rmse:0.109163
# [501]	train-rmse:0.108506
# [502]	train-rmse:0.107867
# [503]	train-rmse:0.107242
# [504]	train-rmse:0.106619
# [505]	train-rmse:0.106016
# [506]	train-rmse:0.105402
# [507]	train-rmse:0.104818
# [508]	train-rmse:0.104222
# [509]	train-rmse:0.103652
# [510]	train-rmse:0.103082
# [511]	train-rmse:0.102527
# [512]	train-rmse:0.101949
# [513]	train-rmse:0.101371
# [514]	train-rmse:0.100813
# [515]	train-rmse:0.100266
# [516]	train-rmse:0.099735
# [517]	train-rmse:0.099177
# [518]	train-rmse:0.098667
# [519]	train-rmse:0.098143
# [520]	train-rmse:0.097614
# [521]	train-rmse:0.097078
# [522]	train-rmse:0.09657
# [523]	train-rmse:0.096085
# [524]	train-rmse:0.095613
# [525]	train-rmse:0.095138
# [526]	train-rmse:0.094663
# [527]	train-rmse:0.094192
# [528]	train-rmse:0.093707
# [529]	train-rmse:0.093245
# [530]	train-rmse:0.092793
# [531]	train-rmse:0.092355
# [532]	train-rmse:0.091925
# [533]	train-rmse:0.091485
# [534]	train-rmse:0.091053
# [535]	train-rmse:0.090606
# [536]	train-rmse:0.090197
# [537]	train-rmse:0.089778
# [538]	train-rmse:0.089347
# [539]	train-rmse:0.088941
# [540]	train-rmse:0.088556
# [541]	train-rmse:0.088167
# [542]	train-rmse:0.087756
# [543]	train-rmse:0.087384
# [544]	train-rmse:0.087003
# [545]	train-rmse:0.086599
# [546]	train-rmse:0.086241
# [547]	train-rmse:0.085887
# [548]	train-rmse:0.085531
# [549]	train-rmse:0.085192
# [550]	train-rmse:0.084845
# [551]	train-rmse:0.084468
# [552]	train-rmse:0.084136
# [553]	train-rmse:0.083802
# [554]	train-rmse:0.083432
# [555]	train-rmse:0.083072
# [556]	train-rmse:0.082757
# [557]	train-rmse:0.082449
# [558]	train-rmse:0.082135
# [559]	train-rmse:0.081792
# [560]	train-rmse:0.081496
# [561]	train-rmse:0.081194
# [562]	train-rmse:0.080904
# [563]	train-rmse:0.080567
# [564]	train-rmse:0.080254
# [565]	train-rmse:0.079978
# [566]	train-rmse:0.07966
# [567]	train-rmse:0.079379
# [568]	train-rmse:0.079086
# [569]	train-rmse:0.07879
# [570]	train-rmse:0.078531
# [571]	train-rmse:0.078245
# [572]	train-rmse:0.077986
# [573]	train-rmse:0.077726
# [574]	train-rmse:0.077444
# [575]	train-rmse:0.077197
# [576]	train-rmse:0.076946
# [577]	train-rmse:0.076661
# [578]	train-rmse:0.076417
# [579]	train-rmse:0.076151
# [580]	train-rmse:0.075924
# [581]	train-rmse:0.075685
# [582]	train-rmse:0.075429
# [583]	train-rmse:0.075191
# [584]	train-rmse:0.074962
# [585]	train-rmse:0.074747
# [586]	train-rmse:0.074532
# [587]	train-rmse:0.074311
# [588]	train-rmse:0.074056
# [589]	train-rmse:0.073843
# [590]	train-rmse:0.073628
# [591]	train-rmse:0.073352
# [592]	train-rmse:0.073123
# [593]	train-rmse:0.072937
# [594]	train-rmse:0.072734
# [595]	train-rmse:0.072553
# [596]	train-rmse:0.072347
# [597]	train-rmse:0.072106
# [598]	train-rmse:0.071918
# [599]	train-rmse:0.071724
# [600]	train-rmse:0.071522
# [601]	train-rmse:0.071288
# [602]	train-rmse:0.071064
# [603]	train-rmse:0.070879
# [604]	train-rmse:0.070654
# [605]	train-rmse:0.070467
# [606]	train-rmse:0.070291
# [607]	train-rmse:0.070092
# [608]	train-rmse:0.069859
# [609]	train-rmse:0.069652
# [610]	train-rmse:0.06949
# [611]	train-rmse:0.069268
# [612]	train-rmse:0.069101
# [613]	train-rmse:0.0689
# [614]	train-rmse:0.068681
# [615]	train-rmse:0.068524
# [616]	train-rmse:0.068324
# [617]	train-rmse:0.06818
# [618]	train-rmse:0.068
# [619]	train-rmse:0.067797
# [620]	train-rmse:0.06761
# [621]	train-rmse:0.067442
# [622]	train-rmse:0.06727
# [623]	train-rmse:0.067072
# [624]	train-rmse:0.066861
# [625]	train-rmse:0.06668
# [626]	train-rmse:0.066515
# [627]	train-rmse:0.066337
# [628]	train-rmse:0.066181
# [629]	train-rmse:0.065993
# [630]	train-rmse:0.065846
# [631]	train-rmse:0.065706
# [632]	train-rmse:0.065514
# [633]	train-rmse:0.065347
# [634]	train-rmse:0.065158
# [635]	train-rmse:0.065032
# [636]	train-rmse:0.06487
# [637]	train-rmse:0.064734
# [638]	train-rmse:0.064611
# [639]	train-rmse:0.064429
# [640]	train-rmse:0.064268
# [641]	train-rmse:0.064131
# [642]	train-rmse:0.063974
# [643]	train-rmse:0.063846
# [644]	train-rmse:0.063711
# [645]	train-rmse:0.063582
# [646]	train-rmse:0.063461
# [647]	train-rmse:0.063311
# [648]	train-rmse:0.063182
# [649]	train-rmse:0.063029
# [650]	train-rmse:0.062905
# [651]	train-rmse:0.062783
# [652]	train-rmse:0.062667
# [653]	train-rmse:0.062529
# [654]	train-rmse:0.062386
# [655]	train-rmse:0.062275
# [656]	train-rmse:0.062157
# [657]	train-rmse:0.06204
# [658]	train-rmse:0.061931
# [659]	train-rmse:0.061812
# [660]	train-rmse:0.061664
# [661]	train-rmse:0.061556
# [662]	train-rmse:0.06141
# [663]	train-rmse:0.061306
# [664]	train-rmse:0.061222
# [665]	train-rmse:0.061131
# [666]	train-rmse:0.060977
# [667]	train-rmse:0.060882
# [668]	train-rmse:0.060753
# [669]	train-rmse:0.060662
# [670]	train-rmse:0.060533
# [671]	train-rmse:0.060427
# [672]	train-rmse:0.060323
# [673]	train-rmse:0.06022
# [674]	train-rmse:0.060125
# [675]	train-rmse:0.060025
# [676]	train-rmse:0.059902
# [677]	train-rmse:0.059811
# [678]	train-rmse:0.059713
# [679]	train-rmse:0.05962
# [680]	train-rmse:0.059522
# [681]	train-rmse:0.059426
# [682]	train-rmse:0.059332
# [683]	train-rmse:0.059215
# [684]	train-rmse:0.059123
# [685]	train-rmse:0.059033
# [686]	train-rmse:0.058953
# [687]	train-rmse:0.058866
# [688]	train-rmse:0.05872
# [689]	train-rmse:0.058642
# [690]	train-rmse:0.058554
# [691]	train-rmse:0.058411
# [692]	train-rmse:0.058299
# [693]	train-rmse:0.058207
# [694]	train-rmse:0.058125
# [695]	train-rmse:0.058044
# [696]	train-rmse:0.057973
# [697]	train-rmse:0.057892
# [698]	train-rmse:0.05782
# [699]	train-rmse:0.057731
# [700]	train-rmse:0.057647
# [701]	train-rmse:0.057538
# [702]	train-rmse:0.057472
# [703]	train-rmse:0.057386
# [704]	train-rmse:0.057304
# [705]	train-rmse:0.057209
# [706]	train-rmse:0.057122
# [707]	train-rmse:0.05703
# [708]	train-rmse:0.056948
# [709]	train-rmse:0.056898
# [710]	train-rmse:0.056824
# [711]	train-rmse:0.056759
# [712]	train-rmse:0.056668
# [713]	train-rmse:0.056603
# [714]	train-rmse:0.056526
# [715]	train-rmse:0.056446
# [716]	train-rmse:0.056389
# [717]	train-rmse:0.056267
# [718]	train-rmse:0.056211
# [719]	train-rmse:0.056147
# [720]	train-rmse:0.056067
# [721]	train-rmse:0.056003
# [722]	train-rmse:0.05593
# [723]	train-rmse:0.055848
# [724]	train-rmse:0.055732
# [725]	train-rmse:0.055691
# [726]	train-rmse:0.055625
# [727]	train-rmse:0.055564
# [728]	train-rmse:0.055525
# [729]	train-rmse:0.055443
# [730]	train-rmse:0.055394
# [731]	train-rmse:0.055331
# [732]	train-rmse:0.055255
# [733]	train-rmse:0.055197
# [734]	train-rmse:0.055137
# [735]	train-rmse:0.055088
# [736]	train-rmse:0.055028
# [737]	train-rmse:0.054953
# [738]	train-rmse:0.054908
# [739]	train-rmse:0.054791
# [740]	train-rmse:0.054738
# [741]	train-rmse:0.054659
# [742]	train-rmse:0.054592
# [743]	train-rmse:0.054514
# [744]	train-rmse:0.054399
# [745]	train-rmse:0.054345
# [746]	train-rmse:0.054283
# [747]	train-rmse:0.054211
# [748]	train-rmse:0.05416
# [749]	train-rmse:0.054099
# [750]	train-rmse:0.054034
# [751]	train-rmse:0.05395
# [752]	train-rmse:0.053913
# [753]	train-rmse:0.053854
# [754]	train-rmse:0.053785
# [755]	train-rmse:0.053733
# [756]	train-rmse:0.053675
# [757]	train-rmse:0.053625
# [758]	train-rmse:0.05357
# [759]	train-rmse:0.053504
# [760]	train-rmse:0.053419
# [761]	train-rmse:0.053361
# [762]	train-rmse:0.053255
# [763]	train-rmse:0.053206
# [764]	train-rmse:0.053165
# [765]	train-rmse:0.053134
# [766]	train-rmse:0.05303
# [767]	train-rmse:0.052977
# [768]	train-rmse:0.052889
# [769]	train-rmse:0.052833
# [770]	train-rmse:0.052783
# [771]	train-rmse:0.052744
# [772]	train-rmse:0.052641
# [773]	train-rmse:0.052593
# [774]	train-rmse:0.052532
# [775]	train-rmse:0.052428
# [776]	train-rmse:0.052379
# [777]	train-rmse:0.052338
# [778]	train-rmse:0.052238
# [779]	train-rmse:0.052193
# [780]	train-rmse:0.052146
# [781]	train-rmse:0.052067
# [782]	train-rmse:0.051998
# [783]	train-rmse:0.051952
# [784]	train-rmse:0.051898
# [785]	train-rmse:0.051834
# [786]	train-rmse:0.051788
# [787]	train-rmse:0.051707
# [788]	train-rmse:0.051662
# [789]	train-rmse:0.051564
# [790]	train-rmse:0.051525
# [791]	train-rmse:0.05148
# [792]	train-rmse:0.051382
# [793]	train-rmse:0.051322
# [794]	train-rmse:0.051268
# [795]	train-rmse:0.051216
# [796]	train-rmse:0.051172
# [797]	train-rmse:0.051077
# [798]	train-rmse:0.051034
# [799]	train-rmse:0.050999
# [800]	train-rmse:0.050962
# [801]	train-rmse:0.050933
# [802]	train-rmse:0.050847
# [803]	train-rmse:0.050811
# [804]	train-rmse:0.050753
# [805]	train-rmse:0.050689
# [806]	train-rmse:0.050655
# [807]	train-rmse:0.05056
# [808]	train-rmse:0.050525
# [809]	train-rmse:0.050461
# [810]	train-rmse:0.050429
# [811]	train-rmse:0.050375
# [812]	train-rmse:0.050341
# [813]	train-rmse:0.050302
# [814]	train-rmse:0.050235
# [815]	train-rmse:0.050182
# [816]	train-rmse:0.050149
# [817]	train-rmse:0.050109
# [818]	train-rmse:0.050075
# [819]	train-rmse:0.049986
# [820]	train-rmse:0.049934
# [821]	train-rmse:0.0499
# [822]	train-rmse:0.04986
# [823]	train-rmse:0.049809
# [824]	train-rmse:0.049778
# [825]	train-rmse:0.049744
# [826]	train-rmse:0.049689
# [827]	train-rmse:0.049657
# [828]	train-rmse:0.049618
# [829]	train-rmse:0.049584
# [830]	train-rmse:0.049545
# [831]	train-rmse:0.04946
# [832]	train-rmse:0.049402
# [833]	train-rmse:0.049339
# [834]	train-rmse:0.049289
# [835]	train-rmse:0.049255
# [836]	train-rmse:0.049222
# [837]	train-rmse:0.049155
# [838]	train-rmse:0.049125
# [839]	train-rmse:0.049076
# [840]	train-rmse:0.049043
# [841]	train-rmse:0.049005
# [842]	train-rmse:0.048975
# [843]	train-rmse:0.048923
# [844]	train-rmse:0.048885
# [845]	train-rmse:0.048847
# [846]	train-rmse:0.04879
# [847]	train-rmse:0.048709
# [848]	train-rmse:0.048653
# [849]	train-rmse:0.048619
# [850]	train-rmse:0.048591
# [851]	train-rmse:0.048531
# [852]	train-rmse:0.048501
# [853]	train-rmse:0.048461
# [854]	train-rmse:0.048403
# [855]	train-rmse:0.048349
# [856]	train-rmse:0.048305
# [857]	train-rmse:0.048267
# [858]	train-rmse:0.04823
# [859]	train-rmse:0.048178
# [860]	train-rmse:0.048125
# [861]	train-rmse:0.048046
# [862]	train-rmse:0.047985
# [863]	train-rmse:0.047927
# [864]	train-rmse:0.047896
# [865]	train-rmse:0.047845
# [866]	train-rmse:0.047816
# [867]	train-rmse:0.047766
# [868]	train-rmse:0.047725
# [869]	train-rmse:0.047681
# [870]	train-rmse:0.047645
# [871]	train-rmse:0.04761
# [872]	train-rmse:0.047572
# [873]	train-rmse:0.047515
# [874]	train-rmse:0.047488
# [875]	train-rmse:0.047428
# [876]	train-rmse:0.047391
# [877]	train-rmse:0.047357
# [878]	train-rmse:0.047319
# [879]	train-rmse:0.047276
# [880]	train-rmse:0.047248
# [881]	train-rmse:0.047197
# [882]	train-rmse:0.04712
# [883]	train-rmse:0.04707
# [884]	train-rmse:0.047037
# [885]	train-rmse:0.04696
# [886]	train-rmse:0.046938
# [887]	train-rmse:0.0469
# [888]	train-rmse:0.046863
# [889]	train-rmse:0.046816
# [890]	train-rmse:0.046783
# [891]	train-rmse:0.046737
# [892]	train-rmse:0.046711
# [893]	train-rmse:0.046685
# [894]	train-rmse:0.046655
# [895]	train-rmse:0.046583
# [896]	train-rmse:0.046558
# [897]	train-rmse:0.046526
# [898]	train-rmse:0.046495
# [899]	train-rmse:0.046447
# [900]	train-rmse:0.046368
# [901]	train-rmse:0.046318
# [902]	train-rmse:0.046278
# [903]	train-rmse:0.046233
# [904]	train-rmse:0.046185
# [905]	train-rmse:0.046148
# [906]	train-rmse:0.04609
# [907]	train-rmse:0.04605
# [908]	train-rmse:0.046018
# [909]	train-rmse:0.045971
# [910]	train-rmse:0.045923
# [911]	train-rmse:0.045879
# [912]	train-rmse:0.045838
# [913]	train-rmse:0.045818
# [914]	train-rmse:0.04577
# [915]	train-rmse:0.045739
# [916]	train-rmse:0.045693
# [917]	train-rmse:0.045646
# [918]	train-rmse:0.045604
# [919]	train-rmse:0.045574
# [920]	train-rmse:0.045553
# [921]	train-rmse:0.045512
# [922]	train-rmse:0.045483
# [923]	train-rmse:0.045428
# [924]	train-rmse:0.045407
# [925]	train-rmse:0.045388
# [926]	train-rmse:0.04534
# [927]	train-rmse:0.045298
# [928]	train-rmse:0.045253
# [929]	train-rmse:0.045213
# [930]	train-rmse:0.04518
# [931]	train-rmse:0.045143
# [932]	train-rmse:0.045094
# [933]	train-rmse:0.045041
# [934]	train-rmse:0.045021
# [935]	train-rmse:0.045002
# [936]	train-rmse:0.044955
# [937]	train-rmse:0.044926
# [938]	train-rmse:0.044886
# [939]	train-rmse:0.044849
# [940]	train-rmse:0.04482
# [941]	train-rmse:0.044799
# [942]	train-rmse:0.044771
# [943]	train-rmse:0.044734
# [944]	train-rmse:0.044691
# [945]	train-rmse:0.044666
# [946]	train-rmse:0.044647
# [947]	train-rmse:0.044601
# [948]	train-rmse:0.044573
# [949]	train-rmse:0.044541
# [950]	train-rmse:0.044502
# [951]	train-rmse:0.044475
# [952]	train-rmse:0.044429
# [953]	train-rmse:0.044411
# [954]	train-rmse:0.044371
# [955]	train-rmse:0.044326
# [956]	train-rmse:0.04428
# [957]	train-rmse:0.044233
# [958]	train-rmse:0.044182
# [959]	train-rmse:0.04415
# [960]	train-rmse:0.044106
# [961]	train-rmse:0.044079
# [962]	train-rmse:0.044046
# [963]	train-rmse:0.044008
# [964]	train-rmse:0.04397
# [965]	train-rmse:0.043935
# [966]	train-rmse:0.043909
# [967]	train-rmse:0.043838
# [968]	train-rmse:0.043802
# [969]	train-rmse:0.04375
# [970]	train-rmse:0.043732
# [971]	train-rmse:0.0437
# [972]	train-rmse:0.043657
# [973]	train-rmse:0.043613
# [974]	train-rmse:0.043554
# [975]	train-rmse:0.043529
# [976]	train-rmse:0.043506
# [977]	train-rmse:0.043484
# [978]	train-rmse:0.043458
# [979]	train-rmse:0.043417
# [980]	train-rmse:0.0434
# [981]	train-rmse:0.043366
# [982]	train-rmse:0.043327
# [983]	train-rmse:0.043304
# [984]	train-rmse:0.043288
# [985]	train-rmse:0.043258
# [986]	train-rmse:0.043233
# [987]	train-rmse:0.0432
# [988]	train-rmse:0.043174
# [989]	train-rmse:0.043149
# [990]	train-rmse:0.043105
# [991]	train-rmse:0.043083
# [992]	train-rmse:0.043048
# [993]	train-rmse:0.043033
# [994]	train-rmse:0.043014
# [995]	train-rmse:0.042971
# [996]	train-rmse:0.042943
# [997]	train-rmse:0.042921
# [998]	train-rmse:0.042891
# [999]	train-rmse:0.042842
# [1000]	train-rmse:0.042817
# [1001]	train-rmse:0.042778
# [1002]	train-rmse:0.042756
# [1003]	train-rmse:0.042735
# [1004]	train-rmse:0.042714
# [1005]	train-rmse:0.042683
# [1006]	train-rmse:0.042667
# [1007]	train-rmse:0.042629
# [1008]	train-rmse:0.042594
# [1009]	train-rmse:0.042567
# [1010]	train-rmse:0.042538
# [1011]	train-rmse:0.042511
# [1012]	train-rmse:0.042486
# [1013]	train-rmse:0.042471
# [1014]	train-rmse:0.042427
# [1015]	train-rmse:0.042413
# [1016]	train-rmse:0.04236
# [1017]	train-rmse:0.042338
# [1018]	train-rmse:0.042317
# [1019]	train-rmse:0.042279
# [1020]	train-rmse:0.042253
# [1021]	train-rmse:0.04221
# [1022]	train-rmse:0.042168
# [1023]	train-rmse:0.042144
# [1024]	train-rmse:0.04213
# [1025]	train-rmse:0.042097
# [1026]	train-rmse:0.042082
# [1027]	train-rmse:0.042046
# [1028]	train-rmse:0.042026
# [1029]	train-rmse:0.041984
# [1030]	train-rmse:0.041955
# [1031]	train-rmse:0.041926
# [1032]	train-rmse:0.0419
# [1033]	train-rmse:0.041874
# [1034]	train-rmse:0.04186
# [1035]	train-rmse:0.041836
# [1036]	train-rmse:0.041788
# [1037]	train-rmse:0.041738
# [1038]	train-rmse:0.041715
# [1039]	train-rmse:0.041669
# [1040]	train-rmse:0.041642
# [1041]	train-rmse:0.041614
# [1042]	train-rmse:0.041563
# [1043]	train-rmse:0.041543
# [1044]	train-rmse:0.0415
# [1045]	train-rmse:0.041481
# [1046]	train-rmse:0.041453
# [1047]	train-rmse:0.041429
# [1048]	train-rmse:0.041403
# [1049]	train-rmse:0.041378
# [1050]	train-rmse:0.041343
# [1051]	train-rmse:0.041324
# [1052]	train-rmse:0.041301
# [1053]	train-rmse:0.041253
# [1054]	train-rmse:0.041225
# [1055]	train-rmse:0.041176
# [1056]	train-rmse:0.041132
# [1057]	train-rmse:0.04111
# [1058]	train-rmse:0.041077
# [1059]	train-rmse:0.041052
# [1060]	train-rmse:0.040992
# [1061]	train-rmse:0.040978
# [1062]	train-rmse:0.040957
# [1063]	train-rmse:0.040933
# [1064]	train-rmse:0.040886
# [1065]	train-rmse:0.040864
# [1066]	train-rmse:0.040828
# [1067]	train-rmse:0.040781
# [1068]	train-rmse:0.040756
# [1069]	train-rmse:0.040735
# [1070]	train-rmse:0.040713
# [1071]	train-rmse:0.040694
# [1072]	train-rmse:0.040661
# [1073]	train-rmse:0.040637
# [1074]	train-rmse:0.040591
# [1075]	train-rmse:0.040572
# [1076]	train-rmse:0.040548
# [1077]	train-rmse:0.040506
# [1078]	train-rmse:0.04049
# [1079]	train-rmse:0.040471
# [1080]	train-rmse:0.040426
# [1081]	train-rmse:0.0404
# [1082]	train-rmse:0.040353
# [1083]	train-rmse:0.040335
# [1084]	train-rmse:0.040286
# [1085]	train-rmse:0.040271
# [1086]	train-rmse:0.04023
# [1087]	train-rmse:0.040183
# [1088]	train-rmse:0.040152
# [1089]	train-rmse:0.040128
# [1090]	train-rmse:0.040088
# [1091]	train-rmse:0.040071
# [1092]	train-rmse:0.040041
# [1093]	train-rmse:0.040016
# [1094]	train-rmse:0.039987
# [1095]	train-rmse:0.039947
# [1096]	train-rmse:0.0399
# [1097]	train-rmse:0.039878
# [1098]	train-rmse:0.039829
# [1099]	train-rmse:0.039805
# [1100]	train-rmse:0.039772
# [1101]	train-rmse:0.039729
# [1102]	train-rmse:0.039711
# [1103]	train-rmse:0.039678
# [1104]	train-rmse:0.039647
# [1105]	train-rmse:0.039623
# [1106]	train-rmse:0.039584
# [1107]	train-rmse:0.039539
# [1108]	train-rmse:0.039509
# [1109]	train-rmse:0.039471
# [1110]	train-rmse:0.039454
# [1111]	train-rmse:0.039431
# [1112]	train-rmse:0.039397
# [1113]	train-rmse:0.039353
# [1114]	train-rmse:0.03933
# [1115]	train-rmse:0.039307
# [1116]	train-rmse:0.039259
# [1117]	train-rmse:0.039242
# [1118]	train-rmse:0.039205
# [1119]	train-rmse:0.039176
# [1120]	train-rmse:0.03913
# [1121]	train-rmse:0.039095
# [1122]	train-rmse:0.039073
# [1123]	train-rmse:0.039039
# [1124]	train-rmse:0.039011
# [1125]	train-rmse:0.038996
# [1126]	train-rmse:0.038961
# [1127]	train-rmse:0.038914
# [1128]	train-rmse:0.038879
# [1129]	train-rmse:0.038845
# [1130]	train-rmse:0.038821
# [1131]	train-rmse:0.038791
# [1132]	train-rmse:0.038751
# [1133]	train-rmse:0.038729
# [1134]	train-rmse:0.038707
# [1135]	train-rmse:0.038688
# [1136]	train-rmse:0.038666
# [1137]	train-rmse:0.038654
# [1138]	train-rmse:0.038637
# [1139]	train-rmse:0.038615
# [1140]	train-rmse:0.038597
# [1141]	train-rmse:0.038564
# [1142]	train-rmse:0.038524
# [1143]	train-rmse:0.038504
# [1144]	train-rmse:0.038458
# [1145]	train-rmse:0.038441
# [1146]	train-rmse:0.038414
# [1147]	train-rmse:0.03837
# [1148]	train-rmse:0.038347
# [1149]	train-rmse:0.038314
# [1150]	train-rmse:0.03828
# [1151]	train-rmse:0.038266
# [1152]	train-rmse:0.038234
# [1153]	train-rmse:0.038199
# [1154]	train-rmse:0.038156
# [1155]	train-rmse:0.038118
# [1156]	train-rmse:0.038087

# %%
lasso_preds = np.expm1(lasso_model.predict(X_test))
final_result=0.8*lasso_preds+0.2*x_pred

solution = pd.DataFrame({"id":test.Id, "SalePrice":final_result}, columns=['id', 'SalePrice'])
solution.to_csv("timestamp1_new_check.csv", index = False)
